# %%
from covid_analysis import *

# %matplotlib inline
sns.set(style="whitegrid")
FIGSIZE = [12, 8]

# %% [markdown]
# # México

# %%
estados_analisis = ["Ciudad de México", "Nuevo León", "Jalisco", "Queretaro"]
estados = load_sinave()
mexico = {}
for ds_name, ds in estados.items():
    mexico[ds_name] = pd.DataFrame({'Mexico': ds.sum(axis=1)})

# %% [markdown]
# ## Resumen

# %% [markdown]
# ### Fecha de Actualización:

# %%
mexico['confirmados'].index[-1].strftime("%d-%m-%Y")
# Out:
# '12-04-2020'

# %% [markdown]
# ### Confirmados

# %%
sum(mexico['confirmados'].iloc[-1])
# Out:
# 4661

# %% [markdown]
# ### Nuevos Confirmados

# %%
sum(mexico['daily_confirmados'].iloc[-1])
# Out:
# 442

# %% [markdown]
# ### Fallecimientos

# %%
sum(mexico['muertos'].iloc[-1])
# Out:
# 296

# %% [markdown]
# ### Nuevos Fallecimientos

# %%
sum(mexico['daily_muertos'].iloc[-1])
# Out:
# 23

# %% [markdown]
# ## Nacional

# %% [markdown]
# ### México: Confirmados acumulados

# %%
analysis(mexico, ["Mexico"], "confirmados", log=True, smooth=False, since=1)
# Out:
#             Mexico
# Date
# 2020-03-30    1094
# 2020-03-31    1215
# 2020-04-01    1378
# 2020-04-02    1510
# 2020-04-03    1688
# 2020-04-04    1890
# 2020-04-05    2143
# 2020-04-06    2439
# 2020-04-07    2785
# 2020-04-08    3181
# 2020-04-09    3441
# 2020-04-10    3844
# 2020-04-11    4219
# 2020-04-12    4661

# %% [markdown]
# ### México: Confirmados diarios

# %%
analysis(mexico, ["Mexico"], "daily_confirmados", since=1, smooth=False, log=False)
# Out:
#             Mexico
# Date
# 2020-03-31     121
# 2020-04-01     163
# 2020-04-02     132
# 2020-04-03     178
# 2020-04-04     202
# 2020-04-05     253
# 2020-04-06     296
# 2020-04-07     346
# 2020-04-08     396
# 2020-04-09     260
# 2020-04-10     403
# 2020-04-11     375
# 2020-04-12     442

# %% [markdown]
# ### México: Fallecimientos acumulados

# %%
analysis(mexico, ["Mexico"], "muertos", since=1, smooth=False, log=True)
# Out:
#             Mexico
# Date
# 2020-03-30      28
# 2020-03-31      29
# 2020-04-01      37
# 2020-04-02      50
# 2020-04-03      60
# 2020-04-04      79
# 2020-04-05      94
# 2020-04-06     125
# 2020-04-07     141
# 2020-04-08     174
# 2020-04-09     194
# 2020-04-10     233
# 2020-04-11     273
# 2020-04-12     296

# %% [markdown]
# ### México: Fallecimientos diarios

# %%
analysis(mexico, ["Mexico"], "daily_muertos", since=None, smooth=False, log=False)
# Out:
#             Mexico
# Date
# 2020-03-31       1
# 2020-04-01       8
# 2020-04-02      13
# 2020-04-03      10
# 2020-04-04      19
# 2020-04-05      15
# 2020-04-06      31
# 2020-04-07      16
# 2020-04-08      33
# 2020-04-09      20
# 2020-04-10      39
# 2020-04-11      40
# 2020-04-12      23

# %% [markdown]
# ### México: Pruebas reportadas por día, acumuladas

# %%
mexico['pruebas'] = mexico['confirmados'].add(mexico['probables']).add(mexico['descartados'])
analysis(mexico, ['Mexico'], 'pruebas', since=1, smooth=False, log=False)
# Out:
#             Mexico
# Date
# 2020-03-30    9481
# 2020-03-31   11008
# 2020-04-01   12278
# 2020-04-02   13985
# 2020-04-03   15686
# 2020-04-04   17184
# 2020-04-05   18034
# 2020-04-06   20475
# 2020-04-07   25410
# 2020-04-08   29578
# 2020-04-09   31496
# 2020-04-10   33893
# 2020-04-11   35479
# 2020-04-12   35301

# %% [markdown]
# ### México: Pruebas reportadas por día

# %%
mexico['daily_pruebas'] = mexico['daily_confirmados'].add(mexico['daily_probables']).add(mexico['daily_descartados'])
analysis(mexico, ["Mexico"], "daily_pruebas", since=None, smooth=False, log=False)
# Out:
#             Mexico
# Date
# 2020-03-31  1527.0
# 2020-04-01  1270.0
# 2020-04-02  1707.0
# 2020-04-03  1701.0
# 2020-04-04  1498.0
# 2020-04-05   850.0
# 2020-04-06  2441.0
# 2020-04-07  4935.0
# 2020-04-08  4168.0
# 2020-04-09  1918.0
# 2020-04-10  2397.0
# 2020-04-11  1586.0
# 2020-04-12     NaN

# %% [markdown]
# ### México: Proporción de confirmados del total de pruebas reportadas por día

# %%
mexico['prop_confirmados'] = mexico['daily_confirmados'] / mexico['daily_pruebas']
analysis(mexico, ['Mexico'], 'prop_confirmados', smooth=False, log=False, since=None)
# Out:
#               Mexico
# Date
# 2020-03-31  0.079240
# 2020-04-01  0.128346
# 2020-04-02  0.077329
# 2020-04-03  0.104644
# 2020-04-04  0.134846
# 2020-04-05  0.297647
# 2020-04-06  0.121262
# 2020-04-07  0.070111
# 2020-04-08  0.095010
# 2020-04-09  0.135558
# 2020-04-10  0.168127
# 2020-04-11  0.236444
# 2020-04-12       NaN

# %% [markdown]
# ## Estados

# %% [markdown]
# ### Estados: Confirmados acumulados

# %%
analysis(estados, estados_analisis, "confirmados", since=1, log=True, smooth=False)
# Out:
# Estado      Ciudad de México  Nuevo León  Jalisco  Queretaro
# Date
# 2020-03-30               205          75       90         27
# 2020-03-31               234          76       94         29
# 2020-04-01               296          78       99         29
# 2020-04-02               327          84      104         32
# 2020-04-03               384          85      116         35
# 2020-04-04               469          88      120         36
# 2020-04-05               560          91      123         38
# 2020-04-06               609          93      126         40
# 2020-04-07               723          93      135         45
# 2020-04-08               855          98      139         47
# 2020-04-09               909         107      139         50
# 2020-04-10              1040         110      144         55
# 2020-04-11              1117         119      150         57
# 2020-04-12              1328         124      156         61

# %% [markdown]
# ### Estados: Confirmados diarios

# %%
analysis(estados, estados_analisis, "daily_confirmados", since=1, log=True, smooth=False)
# Out:
#             Ciudad de México  Nuevo León  Jalisco  Queretaro
# Date
# 2020-03-31                29           1        4          2
# 2020-04-01                62           2        5          0
# 2020-04-02                31           6        5          3
# 2020-04-03                57           1       12          3
# 2020-04-04                85           3        4          1
# 2020-04-05                91           3        3          2
# 2020-04-06                49           2        3          2
# 2020-04-07               114           0        9          5
# 2020-04-08               132           5        4          2
# 2020-04-09                54           9        0          3
# 2020-04-10               131           3        5          5
# 2020-04-11                77           9        6          2
# 2020-04-12               211           5        6          4

# %% [markdown]
# ### Estados: Fallecimmientos diarios

# %%
analysis(estados, estados_analisis, "daily_muertos", since=0, log=False, smooth=False)
# Out:
#             Ciudad de México  Nuevo León  Jalisco  Queretaro
# Date
# 2020-03-31                 0           0        0          0
# 2020-04-01                 0           0        0          0
# 2020-04-02                 5           0        1          0
# 2020-04-03                 2           0        2          1
# 2020-04-04                 2           1        0          0
# 2020-04-05                 2           1        0          0
# 2020-04-06                10           1        1          0
# 2020-04-07                 3           1        0          0
# 2020-04-08                 7           0        1          0
# 2020-04-09                 4           1        0          0
# 2020-04-10                 3           0        1          1
# 2020-04-11                 3           0        2          0
# 2020-04-12                 7           0        0          0

# %% [markdown]
# ### Estados: Trayectorias

# %%
#trajectories(estados, estados_analisis, 'confirmados', since=2, window=3)

# %% [markdown]
# # Mundo

# %%
analysis_countries = ["Mexico", "US", "Spain", "Italy", "Australia", "Korea, South"]
world = load_johns_hopkins()

# %% [markdown]
# ## Mundo: Confirmados acumulados

# %%
analysis(world, analysis_countries, "confirmed")
# Out:
# Country/Region  Mexico      US   Spain   Italy  Australia  Korea, South
# Date
# 2020-03-31        1094  188172   95923  105792       4559          9786
# 2020-04-01        1215  213372  104118  110574       4862          9887
# 2020-04-02        1378  243762  112065  115242       5116          9976
# 2020-04-03        1510  275586  119199  119827       5330         10062
# 2020-04-04        1688  308853  126168  124632       5550         10156
# 2020-04-05        1890  337072  131646  128948       5687         10237
# 2020-04-06        2143  366667  136675  132547       5797         10284
# 2020-04-07        2439  396223  141942  135586       5895         10331
# 2020-04-08        2785  429052  148220  139422       6010         10384
# 2020-04-09        3181  461437  153222  143626       6108         10423
# 2020-04-10        3441  496535  158273  147577       6215         10450
# 2020-04-11        3844  526396  163027  152271       6303         10480
# 2020-04-12        4219  555313  166831  156363       6315         10512
# 2020-04-13        4661  682619  170099  159516       6351         10537

# %% [markdown]
# ## Mundo: Confirmados diarios

# %%
analysis(world, analysis_countries, "daily_confirmed", since=30)
# Out:
#             Mexico      US  Spain  Italy  Australia  Korea, South
# Date
# 2020-03-31     101   26341   7967   4053        198           125
# 2020-04-01     121   25200   8195   4782        303           101
# 2020-04-02     163   30390   7947   4668        254            89
# 2020-04-03     132   31824   7134   4585        214            86
# 2020-04-04     178   33267   6969   4805        220            94
# 2020-04-05     202   28219   5478   4316        137            81
# 2020-04-06     253   29595   5029   3599        110            47
# 2020-04-07     296   29556   5267   3039         98            47
# 2020-04-08     346   32829   6278   3836        115            53
# 2020-04-09     396   32385   5002   4204         98            39
# 2020-04-10     260   35098   5051   3951        107            27
# 2020-04-11     403   29861   4754   4694         88            30
# 2020-04-12     375   28917   3804   4092         12            32
# 2020-04-13     442  127306   3268   3153         36            25

# %% [markdown]
# ## Mundo: Fallecimientos acumulados

# %%
analysis(world, analysis_countries, "deaths", since=3)
# Out:
# Country/Region  Mexico     US  Spain  Italy  Australia  Korea, South
# Date
# 2020-03-31          28   3873   8464  12428         18           162
# 2020-04-01          29   4757   9387  13155         20           165
# 2020-04-02          37   5926  10348  13915         24           169
# 2020-04-03          50   7087  11198  14681         28           174
# 2020-04-04          60   8407  11947  15362         30           177
# 2020-04-05          79   9619  12641  15887         35           183
# 2020-04-06          94  10783  13341  16523         40           186
# 2020-04-07         125  12722  14045  17127         45           192
# 2020-04-08         141  14695  14792  17669         50           200
# 2020-04-09         174  16478  15447  18279         51           204
# 2020-04-10         194  18586  16081  18849         54           208
# 2020-04-11         233  20463  16606  19468         57           211
# 2020-04-12         273  22020  17209  19899         60           214
# 2020-04-13         296  23529  17756  20465         61           217

# %% [markdown]
# ## Mundo: Fallecimientos diarios

# %%
analysis(world, analysis_countries, "daily_deaths", since=3)
# Out:
#             Mexico    US  Spain  Italy  Australia  Korea, South
# Date
# 2020-03-31       8   895    748    837          1             4
# 2020-04-01       1   884    923    727          2             3
# 2020-04-02       8  1169    961    760          4             4
# 2020-04-03      13  1161    850    766          4             5
# 2020-04-04      10  1320    749    681          2             3
# 2020-04-05      19  1212    694    525          5             6
# 2020-04-06      15  1164    700    636          5             3
# 2020-04-07      31  1939    704    604          5             6
# 2020-04-08      16  1973    747    542          5             8
# 2020-04-09      33  1783    655    610          1             4
# 2020-04-10      20  2108    634    570          3             4
# 2020-04-11      39  1877    525    619          3             3
# 2020-04-12      40  1557    603    431          3             3
# 2020-04-13      23  1509    547    566          1             3

# %% [markdown]
# ## Mundo: Trayectorias de casos confirmados

# %%
trajectories(world, analysis_countries, 'confirmed', since=50, window=7)

# %% [markdown]
# ### Revisando

# %%
#Aqui hay algunas diferencias con los datos de FT https://www.ft.com/coronavirus-latest 
#  sobre todo en el número de días, ¿es por el rolling average?
d = world['daily_deaths']['Spain']
d = get_values_since_first_geq(d, 3).reset_index(drop=True)
d = d.rolling(window=7).mean()
d.plot(logy=True)
